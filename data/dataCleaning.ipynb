# %%
#CONSTANTS
init_year = '1970'
ending = '2018'

# %%
#FUNCTIONS
def get_relevant_years(df):
    try:
        df = df[df['DATE'] > init_year]
        return df[df['DATE'] < ending]
    except:
        df = df[df['Date'] > init_year]
        return df[df['Date'] < ending]

# %%
#IMPORTS
import pandas as pd
from functools import reduce

# %%
#Reading in tax info
tax = pd.read_csv('IncomeTaxRates.csv')

# %%
#get_relevant_years(tax)

# %%
#Reading in Funds Rate
funds_rate = pd.read_csv('MonthlyFundsRate.csv')

# %%
#get_relevant_years(funds_rate)

# %%
#Reading in Oil CPI
oil_cpi = pd.read_csv('MonthlyOilCPI.csv')

# %%
#get_relevant_years(oil_cpi)

# %%
#Reading in S&P 500 data
snp = pd.read_csv('MonthlySNPInfo.csv')

# %%
#get_relevant_years(snp)

# %%
gdp = pd.read_csv('RealQuarterlyGDP.csv')

# %%
#get_relevant_years(gdp)

# %%
unemployment = pd.read_csv('QuarterlyUnemploymentSeasonllyAdjusted.csv')
#get_relevant_years(unemployment)

# %%
#dfs = [tax, funds_rate, oil_cpi, snp, gdp, unemployment]
dfs = [get_relevant_years(funds_rate), get_relevant_years(oil_cpi), get_relevant_years(tax), get_relevant_years(unemployment), get_relevant_years(gdp)]

# %%
df_merged = reduce(lambda left,right: pd.merge(left,right,on='DATE', how='outer'), dfs)
df_merged
# Out:
#            DATE  funds_rate  oil_cpi  high_tax_rate  low_tax_rate  \
# 0    1970-01-01        8.98   16.500          71.75          14.0
# 1    1970-02-01        8.98   16.600            NaN           NaN
# 2    1970-03-01        7.76   16.600            NaN           NaN
# 3    1970-04-01        8.10   16.700            NaN           NaN
# 4    1970-05-01        7.94   16.700            NaN           NaN
# 5    1970-06-01        7.60   16.800            NaN           NaN
# 6    1970-07-01        7.21   17.000            NaN           NaN
# 7    1970-08-01        6.61   17.200            NaN           NaN
# 8    1970-09-01        6.29   17.400            NaN           NaN
# 9    1970-10-01        6.20   17.600            NaN           NaN
# 10   1970-11-01        5.60   17.700            NaN           NaN
# 11   1970-12-01        4.90   17.800            NaN           NaN
# 12   1971-01-01        4.14   17.900          70.00          14.0
# 13   1971-02-01        3.72   17.900            NaN           NaN
# 14   1971-03-01        3.71   18.000            NaN           NaN
# 15   1971-04-01        4.15   18.000            NaN           NaN
# 16   1971-05-01        4.63   18.100            NaN           NaN
# 17   1971-06-01        4.91   18.200            NaN           NaN
# 18   1971-07-01        5.31   18.300            NaN           NaN
# 19   1971-08-01        5.56   18.400            NaN           NaN
# 20   1971-09-01        5.55   18.500            NaN           NaN
# 21   1971-10-01        5.20   18.500            NaN           NaN
# 22   1971-11-01        4.91   18.300            NaN           NaN
# 23   1971-12-01        4.14   18.300            NaN           NaN
# 24   1972-01-01        3.50   18.200          70.00          14.0
# 25   1972-02-01        3.29   18.100            NaN           NaN
# 26   1972-03-01        3.83   18.100            NaN           NaN
# 27   1972-04-01        4.17   18.200            NaN           NaN
# 28   1972-05-01        4.27   18.300            NaN           NaN
# 29   1972-06-01        4.46   18.300            NaN           NaN
# ..          ...         ...      ...            ...           ...
# 546  2015-07-01        0.13  257.504            NaN           NaN
# 547  2015-08-01        0.14  248.505            NaN           NaN
# 548  2015-09-01        0.14  241.730            NaN           NaN
# 549  2015-10-01        0.12  241.086            NaN           NaN
# 550  2015-11-01        0.12  240.593            NaN           NaN
# 551  2015-12-01        0.24  226.086            NaN           NaN
# 552  2016-01-01        0.34  216.783          39.60          10.0
# 553  2016-02-01        0.38  211.224            NaN           NaN
# 554  2016-03-01        0.36  211.022            NaN           NaN
# 555  2016-04-01        0.37  214.852            NaN           NaN
# 556  2016-05-01        0.37  222.964            NaN           NaN
# 557  2016-06-01        0.38  231.040            NaN           NaN
# 558  2016-07-01        0.39  230.939            NaN           NaN
# 559  2016-08-01        0.40  229.880            NaN           NaN
# 560  2016-09-01        0.40  230.808            NaN           NaN
# 561  2016-10-01        0.40  236.624            NaN           NaN
# 562  2016-11-01        0.41  236.856            NaN           NaN
# 563  2016-12-01        0.54  243.050            NaN           NaN
# 564  2017-01-01        0.65  250.609          39.60          10.0
# 565  2017-02-01        0.66  250.204            NaN           NaN
# 566  2017-03-01        0.79  248.337            NaN           NaN
# 567  2017-04-01        0.90  250.189            NaN           NaN
# 568  2017-05-01        0.91  246.053            NaN           NaN
# 569  2017-06-01        1.04  243.807            NaN           NaN
# 570  2017-07-01        1.15  241.841            NaN           NaN
# 571  2017-08-01        1.16  251.601            NaN           NaN
# 572  2017-09-01        1.15  261.648            NaN           NaN
# 573  2017-10-01        1.15  262.678            NaN           NaN
# 574  2017-11-01        1.16  272.302            NaN           NaN
# 575  2017-12-01        1.30  272.946            NaN           NaN
#
#      unemployment   real_gdp
# 0        4.169449   4707.112
# 1             NaN        NaN
# 2             NaN        NaN
# 3        4.810251   4715.441
# 4             NaN        NaN
# 5             NaN        NaN
# 6        5.318905   4757.213
# 7             NaN        NaN
# 8             NaN        NaN
# 9        5.824672   4708.281
# 10            NaN        NaN
# 11            NaN        NaN
# 12       5.992794   4834.349
# 13            NaN        NaN
# 14            NaN        NaN
# 15       6.020654   4861.938
# 16            NaN        NaN
# 17            NaN        NaN
# 18       6.134032   4899.950
# 19            NaN        NaN
# 20            NaN        NaN
# 21       5.984506   4914.261
# 22            NaN        NaN
# 23            NaN        NaN
# 24       5.865190   5002.436
# 25            NaN        NaN
# 26            NaN        NaN
# 27       5.780045   5118.278
# 28            NaN        NaN
# 29            NaN        NaN
# ..            ...        ...
# 546      5.187246  16527.587
# 547           NaN        NaN
# 548           NaN        NaN
# 549      5.143721  16547.619
# 550           NaN        NaN
# 551           NaN        NaN
# 552      5.018310  16571.573
# 553           NaN        NaN
# 554           NaN        NaN
# 555      4.970255  16663.516
# 556           NaN        NaN
# 557           NaN        NaN
# 558      4.952021  16778.148
# 559           NaN        NaN
# 560           NaN        NaN
# 561      4.813227  16851.420
# 562           NaN        NaN
# 563           NaN        NaN
# 564      4.667068  16903.240
# 565           NaN        NaN
# 566           NaN        NaN
# 567      4.388430  17031.085
# 568           NaN        NaN
# 569           NaN        NaN
# 570      4.382926  17163.894
# 571           NaN        NaN
# 572           NaN        NaN
# 573      4.156632  17271.702
# 574           NaN        NaN
# 575           NaN        NaN
#
# [576 rows x 7 columns]

# %%
i = -1 #quarter iterator
j = -1 #total iterator

#print(df_merged.values)


for k, row in enumerate(df_merged.values):
    j += 1
    i += 1
    i %= 3
    if i == 1 or i == 2:
        continue
    if j > 573:
        continue
    if k % 12 == 0:
        #get the tax rates
        high_tax_rate = row[3]
        low_tax_rate = row[4]
    
    #get averaged value
    a_oil = row[2]
    b_oil = df_merged.values[k+1][2]
    c_oil = df_merged.values[k+2][2]
    avg_oil = (a_oil + b_oil + c_oil) / 3
    
    a_rate = row[1]
    b_rate = df_merged.values[k+1][1]
    c_rate = df_merged.values[k+2][1]
    avg_rate = (a_rate + b_rate + c_rate) / 3
    
    #set values
    df_merged.set_value(k,'oil_cpi',avg_oil)
    df_merged.set_value(k,'funds_rate', avg_rate)
    df_merged.set_value(k,'high_tax_rate', high_tax_rate)
    df_merged.set_value(k,'low_tax_rate', low_tax_rate)

# %%
df_merged[::3].to_csv('out.csv')
